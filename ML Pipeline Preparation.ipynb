# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import pandas as pd
from sqlalchemy import create_engine
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
nltk.download(['punkt', 'wordnet'])
from sklearn.metrics import classification_report
import numpy as np
from sklearn.model_selection import GridSearchCV
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# load data from database
engine = create_engine('sqlite:///InsertDatabaseName.db')
df = pd.read_sql_table('InsertTableName', engine)
X = df['message']
Y = df.iloc[:, 4:]

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()
    
    lemmatized_tokens = []
    for token in tokens:
        lem = lemmatizer.lemmatize(token).lower().strip()
        lemmatized_tokens.append(lem)
        
    return lemmatized_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
pipeline = Pipeline([
    ('vect', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('clf', MultiOutputClassifier(RandomForestClassifier()))
])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y)
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1))])

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
y_pred = pipeline.predict(X_test)
for index, column in enumerate(y_test):
    print(column, classification_report(y_test[column], y_pred[:, index]))
# Out:
# related_x              precision    recall  f1-score   support
#
#           0       0.60      0.35      0.44      1500
#           1       0.82      0.93      0.87      5011
#           2       0.75      0.14      0.24        43
#
# avg / total       0.77      0.79      0.77      6554
#
# request_x              precision    recall  f1-score   support
#
#           0       0.88      0.98      0.93      5410
#           1       0.83      0.39      0.53      1144
#
# avg / total       0.87      0.88      0.86      6554
#
# offer_x              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6525
#           1       0.00      0.00      0.00        29
#
# avg / total       0.99      1.00      0.99      6554
#
# aid_related_x              precision    recall  f1-score   support
#
#           0       0.73      0.88      0.80      3825
#           1       0.76      0.53      0.63      2729
#
# avg / total       0.74      0.74      0.73      6554
#
# medical_help_x              precision    recall  f1-score   support
#
#           0       0.93      1.00      0.96      6033
#           1       0.62      0.08      0.15       521
#
# avg / total       0.90      0.92      0.90      6554
#
# medical_products_x              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6220
#           1       0.77      0.09      0.16       334
#
# avg / total       0.94      0.95      0.93      6554
#
# search_and_rescue_x              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      6360
#           1       0.62      0.08      0.15       194
#
# avg / total       0.96      0.97      0.96      6554
#
# security_x              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6435
#           1       0.50      0.02      0.03       119
#
# avg / total       0.97      0.98      0.97      6554
#
# military_x              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      6362
#           1       0.48      0.07      0.12       192
#
# avg / total       0.96      0.97      0.96      6554
#
# child_alone_x              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# water_x              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6173
#           1       0.84      0.12      0.22       381
#
# avg / total       0.94      0.95      0.93      6554
#
# food_x              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      5831
#           1       0.81      0.51      0.63       723
#
# avg / total       0.93      0.93      0.93      6554
#
# shelter_x              precision    recall  f1-score   support
#
#           0       0.93      1.00      0.96      5966
#           1       0.84      0.25      0.38       588
#
# avg / total       0.92      0.93      0.91      6554
#
# clothing_x              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6458
#           1       1.00      0.05      0.10        96
#
# avg / total       0.99      0.99      0.98      6554
#
# money_x              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6399
#           1       0.57      0.03      0.05       155
#
# avg / total       0.97      0.98      0.97      6554
#
# missing_people_x              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6478
#           1       1.00      0.01      0.03        76
#
# avg / total       0.99      0.99      0.98      6554
#
# refugees_x              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6340
#           1       0.71      0.02      0.05       214
#
# avg / total       0.96      0.97      0.95      6554
#
# death_x              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6256
#           1       0.89      0.11      0.20       298
#
# avg / total       0.96      0.96      0.94      6554
#
# other_aid_x              precision    recall  f1-score   support
#
#           0       0.87      1.00      0.93      5689
#           1       0.43      0.02      0.04       865
#
# avg / total       0.81      0.87      0.81      6554
#
# infrastructure_related_x              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6133
#           1       0.38      0.01      0.01       421
#
# avg / total       0.90      0.94      0.91      6554
#
# transport_x              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6265
#           1       0.74      0.06      0.11       289
#
# avg / total       0.95      0.96      0.94      6554
#
# buildings_x              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6208
#           1       0.70      0.08      0.15       346
#
# avg / total       0.94      0.95      0.93      6554
#
# electricity_x              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6426
#           1       0.62      0.04      0.07       128
#
# avg / total       0.97      0.98      0.97      6554
#
# tools_x              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6504
#           1       0.00      0.00      0.00        50
#
# avg / total       0.98      0.99      0.99      6554
#
# hospitals_x              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6479
#           1       0.00      0.00      0.00        75
#
# avg / total       0.98      0.99      0.98      6554
#
# shops_x              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6524
#           1       0.00      0.00      0.00        30
#
# avg / total       0.99      1.00      0.99      6554
#
# aid_centers_x              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6475
#           1       0.00      0.00      0.00        79
#
# avg / total       0.98      0.99      0.98      6554
#
# other_infrastructure_x              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6275
#           1       0.25      0.00      0.01       279
#
# avg / total       0.93      0.96      0.94      6554
#
# weather_related_x              precision    recall  f1-score   support
#
#           0       0.84      0.96      0.90      4743
#           1       0.84      0.50      0.63      1811
#
# avg / total       0.84      0.84      0.82      6554
#
# floods_x              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6043
#           1       0.90      0.24      0.38       511
#
# avg / total       0.94      0.94      0.92      6554
#
# storm_x              precision    recall  f1-score   support
#
#           0       0.93      0.99      0.96      5949
#           1       0.76      0.30      0.43       605
#
# avg / total       0.92      0.93      0.91      6554
#
# fire_x              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6485
#           1       0.67      0.03      0.06        69
#
# avg / total       0.99      0.99      0.98      6554
#
# earthquake_x              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.97      5945
#           1       0.90      0.55      0.68       609
#
# avg / total       0.95      0.95      0.95      6554
#
# cold_x              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6405
#           1       0.69      0.07      0.13       149
#
# avg / total       0.97      0.98      0.97      6554
#
# other_weather_x              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6200
#           1       0.45      0.03      0.05       354
#
# avg / total       0.92      0.95      0.92      6554
#
# direct_report_x              precision    recall  f1-score   support
#
#           0       0.86      0.98      0.92      5287
#           1       0.80      0.32      0.46      1267
#
# avg / total       0.85      0.85      0.83      6554
#
# related_y              precision    recall  f1-score   support
#
#           0       0.60      0.35      0.44      1500
#           1       0.82      0.93      0.87      5011
#           2       0.50      0.19      0.27        43
#
# avg / total       0.77      0.79      0.77      6554
#
# request_y              precision    recall  f1-score   support
#
#           0       0.88      0.98      0.93      5410
#           1       0.82      0.36      0.50      1144
#
# avg / total       0.87      0.87      0.85      6554
#
# offer_y              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6525
#           1       0.00      0.00      0.00        29
#
# avg / total       0.99      1.00      0.99      6554
#
# aid_related_y              precision    recall  f1-score   support
#
#           0       0.72      0.87      0.79      3825
#           1       0.75      0.53      0.62      2729
#
# avg / total       0.73      0.73      0.72      6554
#
# medical_help_y              precision    recall  f1-score   support
#
#           0       0.92      1.00      0.96      6033
#           1       0.56      0.07      0.12       521
#
# avg / total       0.90      0.92      0.89      6554
#
# medical_products_y              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6220
#           1       0.62      0.07      0.13       334
#
# avg / total       0.94      0.95      0.93      6554
#
# search_and_rescue_y              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      6360
#           1       0.64      0.05      0.09       194
#
# avg / total       0.96      0.97      0.96      6554
#
# security_y              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6435
#           1       0.17      0.01      0.02       119
#
# avg / total       0.97      0.98      0.97      6554
#
# military_y              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      6362
#           1       0.60      0.09      0.16       192
#
# avg / total       0.96      0.97      0.96      6554
#
# child_alone_y              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# water_y              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6173
#           1       0.89      0.30      0.45       381
#
# avg / total       0.95      0.96      0.95      6554
#
# food_y              precision    recall  f1-score   support
#
#           0       0.93      0.99      0.96      5831
#           1       0.82      0.37      0.51       723
#
# avg / total       0.92      0.92      0.91      6554
#
# shelter_y              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      5966
#           1       0.85      0.31      0.45       588
#
# avg / total       0.93      0.93      0.92      6554
#
# clothing_y              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6458
#           1       0.86      0.06      0.12        96
#
# avg / total       0.98      0.99      0.98      6554
#
# money_y              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6399
#           1       0.67      0.03      0.05       155
#
# avg / total       0.97      0.98      0.97      6554
#
# missing_people_y              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6478
#           1       1.00      0.01      0.03        76
#
# avg / total       0.99      0.99      0.98      6554
#
# refugees_y              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6340
#           1       0.56      0.02      0.04       214
#
# avg / total       0.95      0.97      0.95      6554
#
# death_y              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6256
#           1       0.69      0.13      0.22       298
#
# avg / total       0.95      0.96      0.94      6554
#
# other_aid_y              precision    recall  f1-score   support
#
#           0       0.87      1.00      0.93      5689
#           1       0.53      0.03      0.05       865
#
# avg / total       0.83      0.87      0.81      6554
#
# infrastructure_related_y              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6133
#           1       0.18      0.00      0.01       421
#
# avg / total       0.89      0.93      0.90      6554
#
# transport_y              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6265
#           1       0.56      0.05      0.09       289
#
# avg / total       0.94      0.96      0.94      6554
#
# buildings_y              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6208
#           1       0.80      0.08      0.15       346
#
# avg / total       0.94      0.95      0.93      6554
#
# electricity_y              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6426
#           1       0.67      0.05      0.09       128
#
# avg / total       0.98      0.98      0.97      6554
#
# tools_y              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6504
#           1       0.00      0.00      0.00        50
#
# avg / total       0.98      0.99      0.99      6554
#
# hospitals_y              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6479
#           1       0.00      0.00      0.00        75
#
# avg / total       0.98      0.99      0.98      6554
#
# shops_y              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6524
#           1       0.00      0.00      0.00        30
#
# avg / total       0.99      1.00      0.99      6554
#
# aid_centers_y              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6475
#           1       0.00      0.00      0.00        79
#
# avg / total       0.98      0.99      0.98      6554
#
# other_infrastructure_y              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6275
#           1       0.50      0.01      0.01       279
#
# avg / total       0.94      0.96      0.94      6554
#
# weather_related_y              precision    recall  f1-score   support
#
#           0       0.83      0.96      0.89      4743
#           1       0.83      0.49      0.62      1811
#
# avg / total       0.83      0.83      0.82      6554
#
# floods_y              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6043
#           1       0.88      0.27      0.41       511
#
# avg / total       0.94      0.94      0.93      6554
#
# storm_y              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      5949
#           1       0.75      0.42      0.54       605
#
# avg / total       0.93      0.93      0.92      6554
#
# fire_y              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6485
#           1       0.00      0.00      0.00        69
#
# avg / total       0.98      0.99      0.98      6554
#
# earthquake_y              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      5945
#           1       0.91      0.59      0.71       609
#
# avg / total       0.95      0.96      0.95      6554
#
# cold_y              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6405
#           1       0.67      0.04      0.08       149
#
# avg / total       0.97      0.98      0.97      6554
#
# other_weather_y              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6200
#           1       0.50      0.03      0.06       354
#
# avg / total       0.92      0.95      0.92      6554
#
# direct_report_y              precision    recall  f1-score   support
#
#           0       0.86      0.98      0.91      5287
#           1       0.77      0.33      0.46      1267
#
# avg / total       0.84      0.85      0.83      6554
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('vect',
#    CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#            dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#            lowercase=True, max_df=1.0, max_features=None, min_df=1,
#            ngram_range=(1, 1), preprocessor=None, stop_words=None,
#            strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#            tokenizer=<function tokenize at 0x7f9e40254510>, vocabulary=None)),
#   ('tfidf',
#    TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)),
#   ('clf',
#    MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                max_depth=None, max_features='auto', max_leaf_nodes=None,
#                min_impurity_decrease=0.0, min_impurity_split=None,
#                min_samples_leaf=1, min_samples_split=2,
#                min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#                oob_score=False, random_state=None, verbose=0,
#                warm_start=False),
#               n_jobs=1))],
#  'vect': CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#          lowercase=True, max_df=1.0, max_features=None, min_df=1,
#          ngram_range=(1, 1), preprocessor=None, stop_words=None,
#          strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#          tokenizer=<function tokenize at 0x7f9e40254510>, vocabulary=None),
#  'tfidf': TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True),
#  'clf': MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False),
#             n_jobs=1),
#  'vect__analyzer': 'word',
#  'vect__binary': False,
#  'vect__decode_error': 'strict',
#  'vect__dtype': numpy.int64,
#  'vect__encoding': 'utf-8',
#  'vect__input': 'content',
#  'vect__lowercase': True,
#  'vect__max_df': 1.0,
#  'vect__max_features': None,
#  'vect__min_df': 1,
#  'vect__ngram_range': (1, 1),
#  'vect__preprocessor': None,
#  'vect__stop_words': None,
#  'vect__strip_accents': None,
#  'vect__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'vect__tokenizer': <function __main__.tokenize(text)>,
#  'vect__vocabulary': None,
#  'tfidf__norm': 'l2',
#  'tfidf__smooth_idf': True,
#  'tfidf__sublinear_tf': False,
#  'tfidf__use_idf': True,
#  'clf__estimator__bootstrap': True,
#  'clf__estimator__class_weight': None,
#  'clf__estimator__criterion': 'gini',
#  'clf__estimator__max_depth': None,
#  'clf__estimator__max_features': 'auto',
#  'clf__estimator__max_leaf_nodes': None,
#  'clf__estimator__min_impurity_decrease': 0.0,
#  'clf__estimator__min_impurity_split': None,
#  'clf__estimator__min_samples_leaf': 1,
#  'clf__estimator__min_samples_split': 2,
#  'clf__estimator__min_weight_fraction_leaf': 0.0,
#  'clf__estimator__n_estimators': 10,
#  'clf__estimator__n_jobs': 1,
#  'clf__estimator__oob_score': False,
#  'clf__estimator__random_state': None,
#  'clf__estimator__verbose': 0,
#  'clf__estimator__warm_start': False,
#  'clf__estimator': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False),
#  'clf__n_jobs': 1}

# %%
# n_estimators = [50,100]
# max_features = ['auto', 'sqrt']
# max_depth = [10,20,50,70,100]
# max_depth.append(None)
# min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]


parameters =  {'clf__estimator__min_samples_leaf': min_samples_leaf}

cv = GridSearchCV(pipeline, param_grid=parameters)

cv.fit(X_train, y_train)

cv.best_params_
# Out:
# {'clf__estimator__min_samples_leaf': 1}

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
y_pred = cv.predict(X_test)
for index, column in enumerate(y_test):
    print(column, classification_report(y_test[column], y_pred[:, index]))
# Out:
# related_x              precision    recall  f1-score   support
#
#           0       0.60      0.34      0.44      1500
#           1       0.82      0.93      0.87      5011
#           2       0.62      0.19      0.29        43
#
# avg / total       0.77      0.79      0.77      6554
#
# request_x              precision    recall  f1-score   support
#
#           0       0.88      0.98      0.93      5410
#           1       0.82      0.36      0.50      1144
#
# avg / total       0.87      0.87      0.85      6554
#
# offer_x              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6525
#           1       0.00      0.00      0.00        29
#
# avg / total       0.99      1.00      0.99      6554
#
# aid_related_x              precision    recall  f1-score   support
#
#           0       0.72      0.88      0.79      3825
#           1       0.76      0.52      0.62      2729
#
# avg / total       0.74      0.73      0.72      6554
#
# medical_help_x              precision    recall  f1-score   support
#
#           0       0.92      1.00      0.96      6033
#           1       0.57      0.05      0.10       521
#
# avg / total       0.90      0.92      0.89      6554
#
# medical_products_x              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6220
#           1       0.76      0.08      0.15       334
#
# avg / total       0.94      0.95      0.93      6554
#
# search_and_rescue_x              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      6360
#           1       0.62      0.03      0.05       194
#
# avg / total       0.96      0.97      0.96      6554
#
# security_x              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6435
#           1       0.00      0.00      0.00       119
#
# avg / total       0.96      0.98      0.97      6554
#
# military_x              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      6362
#           1       0.71      0.06      0.11       192
#
# avg / total       0.96      0.97      0.96      6554
#
# child_alone_x              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# water_x              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6173
#           1       0.86      0.33      0.47       381
#
# avg / total       0.95      0.96      0.95      6554
#
# food_x              precision    recall  f1-score   support
#
#           0       0.93      0.99      0.96      5831
#           1       0.81      0.35      0.49       723
#
# avg / total       0.91      0.92      0.91      6554
#
# shelter_x              precision    recall  f1-score   support
#
#           0       0.93      1.00      0.96      5966
#           1       0.84      0.26      0.40       588
#
# avg / total       0.92      0.93      0.91      6554
#
# clothing_x              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6458
#           1       0.80      0.04      0.08        96
#
# avg / total       0.98      0.99      0.98      6554
#
# money_x              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6399
#           1       0.69      0.06      0.11       155
#
# avg / total       0.97      0.98      0.97      6554
#
# missing_people_x              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6478
#           1       0.00      0.00      0.00        76
#
# avg / total       0.98      0.99      0.98      6554
#
# refugees_x              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6340
#           1       0.69      0.04      0.08       214
#
# avg / total       0.96      0.97      0.95      6554
#
# death_x              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6256
#           1       0.76      0.11      0.20       298
#
# avg / total       0.95      0.96      0.94      6554
#
# other_aid_x              precision    recall  f1-score   support
#
#           0       0.87      1.00      0.93      5689
#           1       0.60      0.04      0.07       865
#
# avg / total       0.84      0.87      0.82      6554
#
# infrastructure_related_x              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6133
#           1       0.20      0.00      0.00       421
#
# avg / total       0.89      0.94      0.90      6554
#
# transport_x              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6265
#           1       0.76      0.09      0.16       289
#
# avg / total       0.95      0.96      0.94      6554
#
# buildings_x              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6208
#           1       0.73      0.12      0.20       346
#
# avg / total       0.94      0.95      0.93      6554
#
# electricity_x              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6426
#           1       0.60      0.02      0.05       128
#
# avg / total       0.97      0.98      0.97      6554
#
# tools_x              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6504
#           1       0.00      0.00      0.00        50
#
# avg / total       0.98      0.99      0.99      6554
#
# hospitals_x              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6479
#           1       0.00      0.00      0.00        75
#
# avg / total       0.98      0.99      0.98      6554
#
# shops_x              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6524
#           1       0.00      0.00      0.00        30
#
# avg / total       0.99      1.00      0.99      6554
#
# aid_centers_x              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6475
#           1       0.00      0.00      0.00        79
#
# avg / total       0.98      0.99      0.98      6554
#
# other_infrastructure_x              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6275
#           1       0.25      0.00      0.01       279
#
# avg / total       0.93      0.96      0.94      6554
#
# weather_related_x              precision    recall  f1-score   support
#
#           0       0.85      0.96      0.90      4743
#           1       0.83      0.54      0.66      1811
#
# avg / total       0.84      0.84      0.83      6554
#
# floods_x              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6043
#           1       0.87      0.28      0.42       511
#
# avg / total       0.94      0.94      0.93      6554
#
# storm_x              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      5949
#           1       0.74      0.38      0.50       605
#
# avg / total       0.92      0.93      0.92      6554
#
# fire_x              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6485
#           1       0.00      0.00      0.00        69
#
# avg / total       0.98      0.99      0.98      6554
#
# earthquake_x              precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      5945
#           1       0.91      0.53      0.67       609
#
# avg / total       0.95      0.95      0.95      6554
#
# cold_x              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6405
#           1       0.60      0.02      0.04       149
#
# avg / total       0.97      0.98      0.97      6554
#
# other_weather_x              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6200
#           1       0.36      0.01      0.03       354
#
# avg / total       0.91      0.95      0.92      6554
#
# direct_report_x              precision    recall  f1-score   support
#
#           0       0.86      0.98      0.92      5287
#           1       0.79      0.34      0.47      1267
#
# avg / total       0.85      0.85      0.83      6554
#
# related_y              precision    recall  f1-score   support
#
#           0       0.59      0.35      0.44      1500
#           1       0.82      0.93      0.87      5011
#           2       0.62      0.12      0.20        43
#
# avg / total       0.77      0.79      0.77      6554
#
# request_y              precision    recall  f1-score   support
#
#           0       0.88      0.98      0.93      5410
#           1       0.81      0.38      0.52      1144
#
# avg / total       0.87      0.88      0.86      6554
#
# offer_y              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6525
#           1       0.00      0.00      0.00        29
#
# avg / total       0.99      1.00      0.99      6554
#
# aid_related_y              precision    recall  f1-score   support
#
#           0       0.71      0.88      0.79      3825
#           1       0.75      0.49      0.60      2729
#
# avg / total       0.73      0.72      0.71      6554
#
# medical_help_y              precision    recall  f1-score   support
#
#           0       0.92      1.00      0.96      6033
#           1       0.57      0.06      0.11       521
#
# avg / total       0.90      0.92      0.89      6554
#
# medical_products_y              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6220
#           1       0.86      0.06      0.11       334
#
# avg / total       0.95      0.95      0.93      6554
#
# search_and_rescue_y              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      6360
#           1       0.64      0.04      0.07       194
#
# avg / total       0.96      0.97      0.96      6554
#
# security_y              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6435
#           1       0.17      0.01      0.02       119
#
# avg / total       0.97      0.98      0.97      6554
#
# military_y              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      6362
#           1       0.63      0.10      0.17       192
#
# avg / total       0.96      0.97      0.96      6554
#
# child_alone_y              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# water_y              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6173
#           1       0.79      0.13      0.22       381
#
# avg / total       0.94      0.95      0.93      6554
#
# food_y              precision    recall  f1-score   support
#
#           0       0.92      0.99      0.95      5831
#           1       0.81      0.32      0.46       723
#
# avg / total       0.91      0.92      0.90      6554
#
# shelter_y              precision    recall  f1-score   support
#
#           0       0.93      1.00      0.96      5966
#           1       0.83      0.20      0.32       588
#
# avg / total       0.92      0.92      0.90      6554
#
# clothing_y              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6458
#           1       1.00      0.06      0.12        96
#
# avg / total       0.99      0.99      0.98      6554
#
# money_y              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6399
#           1       0.62      0.03      0.06       155
#
# avg / total       0.97      0.98      0.97      6554
#
# missing_people_y              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6478
#           1       1.00      0.03      0.05        76
#
# avg / total       0.99      0.99      0.98      6554
#
# refugees_y              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6340
#           1       0.67      0.07      0.12       214
#
# avg / total       0.96      0.97      0.96      6554
#
# death_y              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6256
#           1       0.84      0.09      0.16       298
#
# avg / total       0.95      0.96      0.94      6554
#
# other_aid_y              precision    recall  f1-score   support
#
#           0       0.87      1.00      0.93      5689
#           1       0.51      0.02      0.04       865
#
# avg / total       0.82      0.87      0.81      6554
#
# infrastructure_related_y              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6133
#           1       0.33      0.00      0.01       421
#
# avg / total       0.90      0.94      0.91      6554
#
# transport_y              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6265
#           1       0.68      0.07      0.12       289
#
# avg / total       0.95      0.96      0.94      6554
#
# buildings_y              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6208
#           1       0.74      0.12      0.21       346
#
# avg / total       0.94      0.95      0.93      6554
#
# electricity_y              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6426
#           1       0.75      0.07      0.13       128
#
# avg / total       0.98      0.98      0.97      6554
#
# tools_y              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6504
#           1       0.00      0.00      0.00        50
#
# avg / total       0.98      0.99      0.99      6554
#
# hospitals_y              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6479
#           1       0.00      0.00      0.00        75
#
# avg / total       0.98      0.99      0.98      6554
#
# shops_y              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6524
#           1       0.00      0.00      0.00        30
#
# avg / total       0.99      1.00      0.99      6554
#
# aid_centers_y              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6475
#           1       0.00      0.00      0.00        79
#
# avg / total       0.98      0.99      0.98      6554
#
# other_infrastructure_y              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6275
#           1       0.20      0.00      0.01       279
#
# avg / total       0.93      0.96      0.94      6554
#
# weather_related_y              precision    recall  f1-score   support
#
#           0       0.84      0.96      0.90      4743
#           1       0.83      0.52      0.64      1811
#
# avg / total       0.84      0.84      0.82      6554
#
# floods_y              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6043
#           1       0.91      0.31      0.46       511
#
# avg / total       0.94      0.94      0.93      6554
#
# storm_y              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      5949
#           1       0.76      0.33      0.46       605
#
# avg / total       0.92      0.93      0.92      6554
#
# fire_y              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6485
#           1       0.67      0.03      0.06        69
#
# avg / total       0.99      0.99      0.98      6554
#
# earthquake_y              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      5945
#           1       0.89      0.60      0.72       609
#
# avg / total       0.95      0.96      0.95      6554
#
# cold_y              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6405
#           1       0.74      0.13      0.23       149
#
# avg / total       0.97      0.98      0.97      6554
#
# other_weather_y              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6200
#           1       0.41      0.03      0.05       354
#
# avg / total       0.92      0.95      0.92      6554
#
# direct_report_y              precision    recall  f1-score   support
#
#           0       0.86      0.98      0.92      5287
#           1       0.82      0.32      0.46      1267
#
# avg / total       0.85      0.86      0.83      6554
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
import pickle
filename = 'disaster_response_ML_pipeline.pkl'
pickle.dump(cv, open(filename, 'wb'))

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
